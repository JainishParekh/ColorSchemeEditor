# %%
import numpy as np
import cv2

# %%
img = cv2.imread('static/uploads/Resume_Profile.jpg')

# %%
print(img)
# Out:
# [[[125 149 167]
#   [126 150 168]
#   [127 151 169]
#   ...
#   [ 51  56  77]
#   [ 51  56  77]
#   [ 51  56  77]]
#
#  [[123 147 165]
#   [124 148 166]
#   [127 151 169]
#   ...
#   [ 58  63  84]
#   [ 58  63  84]
#   [ 58  63  84]]
#
#  [[123 147 165]
#   [125 149 167]
#   [127 151 169]
#   ...
#   [ 61  66  87]
#   [ 61  66  87]
#   [ 61  66  87]]
#
#  ...
#
#  [[190 128  74]
#   [190 128  74]
#   [190 128  74]
#   ...
#   [215 172  99]
#   [215 172  99]
#   [215 172  99]]
#
#  [[191 129  75]
#   [191 129  75]
#   [191 129  75]
#   ...
#   [217 174 101]
#   [217 174 101]
#   [217 174 101]]
#
#  [[191 129  75]
#   [191 129  75]
#   [191 129  75]
#   ...
#   [220 177 104]
#   [220 177 104]
#   [220 177 104]]]

# %%
img.shape
# Out:
# (1280, 875, 3)

# %%
h,w,c = img.shape

# %%
for y in range(h):
    for x in range(w):
        (r,g,b) = tuple(img[y,x])
        print(r,g,b)
# Out:
# 125 149 167
# 126 150 168
# 127 151 169
# 130 154 172
# 132 156 174
# 134 158 176
# 136 160 178
# 137 161 179
# 141 165 183
# 141 165 183
# 142 166 184
# 143 167 185
# 143 167 185
# 144 168 186
# 145 169 187
# 145 169 187
# 143 166 188
# 143 166 188
# 143 166 188
# 143 166 188
# 143 166 188
# 143 166 188
# 143 166 188
# 143 166 188
# 142 165 187
# 141 164 186
# 141 164 186
# 141 164 186
# 142 165 187
# 144 167 189
# 146 169 191
# 148 171 193
# 152 170 193
# 152 171 192
# 153 167 189
# 141 155 173
# 119 130 144
# 88 97 107
# 59 65 72
# 40 44 49
# 27 30 34
# 19 22 26
# 16 20 25
# 15 21 26
# 10 15 24
# 12 21 30
# 50 58 71
# 88 104 117
# 121 142 163
# 110 137 158
# 116 143 164
# 134 161 182
# 141 168 189
# 135 162 183
# 133 160 181
# 139 166 187
# 134 161 182
# 134 161 182
# 135 162 183
# 136 163 184
# 136 163 184
# 137 164 185
# 138 165 186
# 138 165 186
# 141 168 189
# 137 164 185
# 132 159 180
# 131 158 179
# 134 161 182
# 137 164 185
# 138 165 186
# 137 164 185
# 134 161 182
# ...
